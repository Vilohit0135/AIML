# %% [markdown]
# # Student name: Vilohit Keshava Murthy Achar

# %% [markdown]
# # Student ID: 23077751

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut

# %% [markdown]
# # Task 1a

# %% [markdown]
# These functions are provided to assist you in Task 1a

# %%
def point_on_boundary(weights, x):
    """ Return the y-position on the boundary based on given x-position.  """
    return -(weights[0]+weights[1]*x)/weights[2]

# %%
def decision_boundary(weights, x_min, x_max):
    """ Return two points on the decision boundary: one at x_min and one at x_max """
    return [pointOnBoundary(x_min), pointOnBoundary(x_max)]

# %% [markdown]
# - Train scikit-learn’s Logistic Regression algorithm using the Et2_Classification_TrainingData.csv dataset provided in the repository without adding extra features to those provided.
#
#
#
#
# - Test the performance of your model using the Et2_Classification_TestData.csv dataset.

# %%
training_data = pd.read_csv('/content/Et2_Classification_TrainingData.csv', header=None)
testing_data = pd.read_csv('/content/Et2_Classification_TestData.csv', header=None)

# %%
features = training_data.iloc[:, 0:2]
labels = training_data.iloc[:, 2:]
print(features)
print(labels)
# Out:
#            0         1
# 0   0.654862  0.326862
# 1   0.910476 -0.076881
# 2  -0.001699 -0.823829
# 3   0.445977 -0.670031
# 4   0.458449  0.576294
# ..       ...       ...
# 65  0.304020  0.750958
# 66 -0.908438 -0.265756
# 67 -0.738828  0.787035
# 68  0.841322  0.467849
# 69  0.360446 -0.760239
#
# [70 rows x 2 columns]
#       2
# 0   1.0
# 1  -1.0
# 2   1.0
# 3   1.0
# 4   1.0
# ..  ...
# 65  1.0
# 66 -1.0
# 67 -1.0
# 68  1.0
# 69 -1.0
#
# [70 rows x 1 columns]

# %%
features_train = training_data.drop(2, axis=1)
labels_train = training_data[2]
features_train.columns = ['feature_1', 'feature_2']

# %%
features_test = testing_data.iloc[:, 0:2]
labels_test = testing_data.iloc[:, 2]
print(features_test)
print(labels_test)
# Out:
#            0         1
# 0  -0.489264  0.556336
# 1   0.053777 -0.889851
# 2  -0.362713  0.688486
# 3   0.458583 -0.488764
# 4   0.783507  0.216594
# 5   0.026664  1.007801
# 6   0.686773 -0.833234
# 7   1.007354 -0.204875
# 8  -0.401635 -0.882016
# 9   0.856453 -0.323817
# 10 -0.559200 -0.774541
# 11 -0.369396 -0.616509
# 12  0.014726  0.742483
# 13 -0.858163 -0.490894
# 14  0.586947 -0.257329
# 15  0.759550  0.052192
# 16 -0.637100 -0.584927
# 17  0.069206 -0.764305
# 18  0.806887 -0.601560
# 19 -0.755405  0.216479
# 20 -0.704567  0.228863
# 21 -0.015940  0.708253
# 22 -0.931673  0.670793
# 23 -0.865186  0.393750
# 24 -0.668755 -0.647327
# 25  0.208431  0.903712
# 26  0.572123  0.795296
# 27  0.753251 -0.634668
# 28 -0.511770 -0.716742
# 29  0.540136 -0.425933
# 0     1.0
# 1    -1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5    -1.0
# 6    -1.0
# 7    -1.0
# 8    -1.0
# 9     1.0
# 10   -1.0
# 11    1.0
# 12    1.0
# 13   -1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# ...

# %%
features_test = testing_data.drop(2, axis=1)
labels_test = testing_data[2]
features_test.columns = ['feature_1', 'feature_2']

# %%
classifier = LogisticRegression()
classifier.fit(features, labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
train_accuracy = classifier.score(features, labels)
print(train_accuracy)
test_score = classifier.score(features_test, labels_test)
print(test_score)
# Out:
# 0.4714285714285714
# 0.36666666666666664
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
labels_train_pred = classifier.predict(features_train)
Ein = np.mean(labels_train != labels_train_pred)
labels_test_pred = classifier.predict(features_test)
Eout = np.mean(labels_test != labels_test_pred)
print("In-sample error:", Ein)
print("Out-of-sample error:", Eout)
# Out:
# In-sample error: 0.5285714285714286
# Out-of-sample error: 0.6333333333333333
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
plt.scatter(features[0], features[1], c=labels)
plt.xlabel('feature  values')
plt.ylabel('label values')
plt.title('Training data')
plt.plot()
# Out:
# []

# %%
plt.scatter(features_test[0], features_test[1], c=labels_test)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Testing data')
plt.plot()
# Out:
# []

# %% [markdown]
# - Observe your results and explain why these results seem disappointing (record your thoughts in a Markdown cell in your notebook).

# %% [markdown]
# # Answer
# After observing the acuuracy of the classifier it is reduced in the test data, where can say that the classifer is not able to classify  the new data point provided in test data. And we say the two classes are not linearly separable.
# This can the result of data quality or model complexity.

# %% [markdown]
# Please add cells according to your own requirements.

# %% [markdown]
# - Now choose suitable new features and use these to improve the classification performance.

# %%
features_train['feature_1_squared'] = features_train['feature_1'] ** 2
features_train['feature_2_squared'] = features_train['feature_2'] ** 2
features_train.head()
# Out:
#    feature_1  feature_2  feature_1_squared  feature_2_squared
# 0   0.654862   0.326862           0.428844           0.106839
# 1   0.910476  -0.076881           0.828967           0.005911
# 2  -0.001699  -0.823829           0.000003           0.678694
# 3   0.445977  -0.670031           0.198896           0.448941
# 4   0.458449   0.576294           0.210175           0.332115

# %%
features_test['feature_1_squared'] = features_test.iloc[:, 0] ** 2
features_test['feature_2_squared'] = features_test.iloc[:, 1] ** 2
features_test.head()
# Out:
#    feature_1  feature_2  feature_1_squared  feature_2_squared
# 0  -0.489264   0.556336           0.239379           0.309509
# 1   0.053777  -0.889851           0.002892           0.791834
# 2  -0.362713   0.688486           0.131561           0.474013
# 3   0.458583  -0.488764           0.210299           0.238890
# 4   0.783507   0.216594           0.613883           0.046913

# %%
classifier2 = LogisticRegression()
classifier2.fit(features_train[['feature_1_squared', 'feature_2_squared']], labels_train)
# Out:
# LogisticRegression()

# %%
plt.scatter(features_test['feature_1_squared'], features_test['feature_2_squared'], c=labels_test, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.xlabel('Feature_1_squared')
plt.ylabel('Feature_2_squared')
# Out:
# Text(0, 0.5, 'Feature_2_squared')

# %%
labels_train_pred1 = classifier2.predict(features_train[['feature_1_squared', 'feature_2_squared']])
Ein1 = np.mean(labels_train != labels_train_pred1)
labels_test_pred1 = classifier2.predict(features_test[['feature_1_squared', 'feature_2_squared']])
Eout1 = np.mean(labels_test != labels_test_pred1)

print("Ein :", Ein1)
print("Eout :", Eout1)
# Out:
# Ein : 0.08571428571428572
# Eout : 0.1

# %%
train_accuracy = 1 - Ein1
test_accuracy = 1 - Eout1

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9142857142857143
# Test Accuracy: 0.9

# %% [markdown]
# # Raised to 3

# %%
features_train['feature_1_raisedto3'] = features_train['feature_1'] ** 3
features_train['feature_2_raisedto3'] = features_train['feature_2'] ** 3
features_train.head()
# Out:
#    feature_1  feature_2  feature_1_squared  feature_2_squared  \
# 0   0.654862   0.326862           0.428844           0.106839
# 1   0.910476  -0.076881           0.828967           0.005911
# 2  -0.001699  -0.823829           0.000003           0.678694
# 3   0.445977  -0.670031           0.198896           0.448941
# 4   0.458449   0.576294           0.210175           0.332115
#
#    feature_1_raisedto3  feature_2_raisedto3
# 0         2.808337e-01             0.034922
# 1         7.547546e-01            -0.000454
# 2        -4.907610e-09            -0.559128
# 3         8.870289e-02            -0.300804
# 4         9.635466e-02             0.191396

# %%
features_test['feature_1_raisedto3'] = features_test.iloc[:, 0] ** 3
features_test['feature_2_raisedto3'] = features_test.iloc[:, 1] ** 3
features_test.head()
# Out:
#    feature_1  feature_2  feature_1_squared  feature_2_squared  \
# 0  -0.489264   0.556336           0.239379           0.309509
# 1   0.053777  -0.889851           0.002892           0.791834
# 2  -0.362713   0.688486           0.131561           0.474013
# 3   0.458583  -0.488764           0.210299           0.238890
# 4   0.783507   0.216594           0.613883           0.046913
#
#    feature_1_raisedto3  feature_2_raisedto3
# 0            -0.117120             0.172191
# 1             0.000156            -0.704614
# 2            -0.047719             0.326351
# 3             0.096439            -0.116761
# 4             0.480981             0.010161

# %%
classifier3 = LogisticRegression()
classifier3.fit(features_train[['feature_1_raisedto3', 'feature_2_raisedto3']], labels_train)
# Out:
# LogisticRegression()

# %%
plt.scatter(features_test['feature_1_raisedto3'], features_test['feature_2_raisedto3'], c=labels_test, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.xlabel('Feature_1_raisedto3')
plt.ylabel('Feature_2_raisedto3')
# Out:
# Text(0, 0.5, 'Feature_2_raisedto3')

# %%
labels_train_pred1 = classifier3.predict(features_train[['feature_1_raisedto3', 'feature_2_raisedto3']])
Ein3 = np.mean(labels_train != labels_train_pred1)
labels_test_pred1 = classifier3.predict(features_test[['feature_1_raisedto3', 'feature_2_raisedto3']])
Eout3 = np.mean(labels_test != labels_test_pred1)

print("Ein :", Ein3)
print("Eout :", Eout3)
# Out:
# Ein : 0.5857142857142857
# Eout : 0.7666666666666667

# %%
train_accuracy3 = 1 - Ein3
test_accuracy3 = 1 - Eout3

print("Training Accuracy:", train_accuracy3)
print("Test Accuracy:", test_accuracy3)
# Out:
# Training Accuracy: 0.41428571428571426
# Test Accuracy: 0.23333333333333328

# %% [markdown]
# - Observe and explain (use plots where appropriate) why the classification performance has improved.

# %% [markdown]
# We can see that there is an improvement in the accuracy and there is very less difference from the test and train error and accuracy. So we can tell the second classifier is good . Also looking at the diagram above where we draw a line to separate two groups of points, we notice that the points are spread out evenly around the middle point. The groups also look like circles, with one circle overlapping the other. When we square the numbers representing the points, it helps to draw a straight line to separate the circles better. This makes it easier for the computer to tell the two groups apart, so it works better overall.

# %% [markdown]
# ## Reflection
#
# After engaging with your peers, reflect on this task and answer the following questions:
# - How do the found values for Ein and Eout for the various models relate to model complexity?
# - Explain how data transformations can lead to linear separability of a dataset.
# - Explain how data transformations effect the complexity of your model.

# %% [markdown]
# Your reflection..

# %% [markdown]
# -  Data transformations play a main role in enhancing the separability of datasets, often by reshaping the feature space to facilitate linear separability. As you can see by  applying transformations such as squaring or raising features to higher powers like i have done above, non-linear relationships in the data can be transformed into linear ones, making it easier for linear classifiers to effectively discriminate between different classes. These transformations enable me to develop new features that better capture the underlying patterns in the data, ultimately leading to simpler decision boundaries and improved model performance.
#
# - As mentioned above by data transformation like squaring the data and raisning it by 3, we are to see linear separability in the scatter plot shown above. By sqaring the features the non- lienar relationship can be transformed to linear ones. The data transformations enable the model to find a simpler decision boundary in the transformed feature space, thereby improving its ability to classify the data accurately. This demonstrates how data transformations can facilitate linear separability and enhance the performance of classifiers.
#
# - In this scenario, the transformations applied to the features, such as squaring them (`features_1_sqared` and `features_2_squared`) and also raised to the power of 3 , impact the model's complexity by altering the feature space representation. Specifically, squaring the features increases the dimensionality of the feature space, potentially adding complexity to the model. While a more complex model may have a greater capacity to capture intricate patterns in the data, it also introduces the risk of overfitting.

# %% [markdown]
# # Task 1b

# %%
def weights(X,y):
    '''Returns the weight vector associated with the regression line that best describes the data X,y in an MSE fashion '''
    # add bias 1 to inputs X
    X = np.concatenate((np.ones((X.shape[0],1)),X.reshape(X.shape[0],X.shape[1])),axis=1)
    # Calculation of weights using pseudo-inverse.
    return np.linalg.inv((X.T.dot(X))).dot(X.T).dot(y)

# %%
def linreg_predict(w,X):
    ''' Returns a prediction y for data point X for a linear regression described by weights w '''
    # add bias 1 to inputs X
    X = np.concatenate((np.ones((X.shape[0],1)),X.reshape(X.shape[0],X.shape[1])),axis=1)

    # Calculation of outputs given weights and data (X).
    out=[]
    for x in X:
        out.append(w.T.dot(x))
    return np.array(out)

# %%
def calc_error(w,X,y):
    # Calculate the error as the mean squared error
    pred = linreg_predict(w,X)
    return (pred-np.array(y)).dot(pred-np.array(y))/len(X)

# %%
def transPoly(X, power):
    # Extend the data in X with a bias (1) and powers of the feature up to 'power'
    extra=[]
    for x in X:
        row=[]
        for p in range(2,power+1):
            row.append(x**p)
        extra.append(row)
    return np.concatenate((X.reshape(len(X),1),np.array(extra)),1)

# %% [markdown]
# To prevent results due to luck, it is useful to repeat your experiments a good few times and look at average results. The below code snippet may be useful in this regard.

# %%
error_in = []
error_out = []
repeats = 100
power_range = range(low_powers, high_powers) # it is up to you to decide on a suitable range

for power in power_range:
    e_in=0
    e_out=0
    for r in range(repeats):
        X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=XX) ##Choose a suitable training_size XX
        X_train_trans = ## implement your data transformation
        X_test_trans = ## implement your data transformation
        w = weights(X_train_trans,y_train)
        e_in += calc_error(w,X_train_trans,y_train)
        e_out+= calc_error(w,X_test_trans,y_test)
    error_in.append(e_in/repeats)
    error_out.append(e_out/repeats)

# %% [markdown]
# Please add cells according to your own requirements.

# %% [markdown]
# ## Reflection
# After engaging with your peers, reflect on this task and answer the following questions:
# - How does the plot of Ein and Eout versus degree of the used polynomial data transformation relate to model complexity?
# - How can the choice of transformation that yielded the best results be explained in terms of sample complexity?

# %% [markdown]
# Your reflection..

# %% [markdown]
# # Task 2

# %% [markdown]
# Below is an implementation of linear regression with regularization

# %%
def weights_reg(X,y,l):
    '''Returns the weight vector associated with the regression line that best describes the data X,y in an MSE fashion
    including a weight regularisation penalty term controlled using l '''
    # add bias 1 to inputs X
    X = np.concatenate((np.ones((X.shape[0],1)),X.reshape(X.shape[0],X.shape[1])),axis=1)
    n = len(X)
    m=X.T.dot(X)
    return np.linalg.inv(m+l*np.identity(m.shape[0])).dot(X.T).dot(y)

# %%
data_frame = pd.read_csv('/content/ET2_Regression_Data.csv', header=None)
X = data_frame.iloc[:, 0].values
y= data_frame.iloc[:, 1].values

# %% [markdown]
# This code snippet may be useful to keep track of Ein, Eout and the corresponding weights for various regulariser parameters

# %%
ein=[]
eout=[]
weights=[]
lambdas = np.linspace(0, 0.5, 1000)
X_trans = transPoly(X,50)
optimal_lambda = 0
min_eout = float('inf')
# random_state fixed to get reproducible (and 'good'! :-)) results
X_train, X_test, y_train, y_test = train_test_split(X_trans, y, train_size=0.5, random_state =5)
for l in lambdas:
    w = weights_reg(X_train,y_train,l)
    ein.append(calc_error(w,X_train,y_train))
    eout_curr = calc_error(w, X_test, y_test)
    eout.append(calc_error(w,X_test,y_test))
    weights.append(w)
    if eout_curr < min_eout:
        min_eout = eout_curr
        opt_lambda = l

plt.plot(lambdas,eout)
plt.show()

# %%
print(f"Optimal Regularization Parameter: {opt_lambda}")
print(f"Eout without optimal lambda: {calc_error(weights_reg(X_train, y_train, 0), X_test, y_test)}")
print(f"Eout with optimal lambda={round(opt_lambda, 3)}: {min_eout}")
# Out:
# Optimal Regularization Parameter: 0.022022022022022022
# Eout without optimal lambda: 253640350.16026375
# Eout with optimal lambda=0.022: 0.02576333664795419

# %%
plt.plot(lambdas, eout)
plt.title('Model Performance vs. Lambda')
plt.xlabel('Lambda')
plt.ylabel('Mean Squared Error')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

# Plot Eout
ax1.plot(lambdas, eout, label='Eout', color='blue')
ax1.set_ylabel('Mean Squared Error')
ax1.set_title('Model Performance vs. Regularization Parameter (Lambda)')
ax1.legend()

# Plot Ein
ax2.plot(lambdas, ein, label='Ein', color='green')
ax2.set_xlabel('Regularization Parameter (Lambda)')
ax2.set_ylabel('Mean Squared Error')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
overfitted_lambda = 0.00001
underfitted_lambda = 0.5

# Calculate weights for different regularization parameters
weights_underfitted = weights_reg(X_train, y_train, underfitted_lambda)
weights_optimal = weights_reg(X_train, y_train, opt_lambda)
weights_overfitted = weights_reg(X_train, y_train, overfitted_lambda)

w_without_reg = weights_reg(X_train, y_train, 0)
eout_without_reg = calc_error(w_without_reg, X_test, y_test)

print(f"Optimal Regularization Parameter (lambda): {optimal_lambda}")
print(f"Eout without regularization: {eout_without_reg}")
print(f"Eout with optimal regularization (lambda={optimal_lambda}): {min_eout}")

# Plot the weights
plt.figure(figsize=(15, 5))

# Plot for underfitted model
plt.subplot(1, 3, 1)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_underfitted, X_trans), color='orange', linestyle='--', label='Fitted model')
plt.title('Underfitted Model (λ=0.5)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# Plot for optimal model
plt.subplot(1, 3, 2)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_optimal, X_trans), color='green', linestyle='--', label='Fitted model')
plt.title(f'Optimal Model (λ={round(opt_lambda, 3)})')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# Plot for overfitted model
plt.subplot(1, 3, 3)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_overfitted, X_trans), color='red', linestyle='--', label='Fitted model')
plt.title('Overfitted Model (λ=0.00001)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Optimal Regularization Parameter (lambda): 0
# Eout without regularization: 253640350.16026375
# Eout with optimal regularization (lambda=0): 0.02576333664795419

# %% [markdown]
# Please add cells according to your own requirements.

# %% [markdown]
# ## Reflection

# %% [markdown]
# In your reflection, makes sure to answer the following questions:
# - Interpret the information in the requested figures.
# - Explain the strategy chosen to decide on the optimum amount of regularisation.
# - Explain the effect of the term l*np.identity(m.shape[0]) in the pseudo-inverse.

# %% [markdown]
# # Answer:-
#
# 1.
# Here I have checked how changing the parameters of regularization imapcts the models Ein and Eout in the above plot. To check, I set this parameter to a wide range of values . I treid to find the best spot where the error is the lowest since this indicates that my model is peroming at its highest level of prediction accuracy. By plotting errors against different values for the regularization parameter, I can easily spot which one makes my model work best. The best value is the lowest point on the plot. It's all about finding the right balance. I need to make sure I'm not using too much or too little of this parameter to avoid making my model too simple or too complex.
#
# 2.
# In order to avoid overfitting, or the model fitting the training data too closely, I set out to determine the ideal degree of regularization for my linear regression model. I tested with regularization values ranging from 0 to 0.5 and saw how they affected the model's out-of-sample error, a measure of the model's ability to generalize to new data. I could see which parameter was optimal by visually comparing these mistakes to the regularization values; the lowest spot on the plot indicated the optimum parameter. Using this method, I was able to determine the model's ideal ratio of complexity to simplicity, which resulted in precise forecasts. My approach was based on real-world testing and used trial and error to determine the best regularization strategy to improve the model's performance.
#
#
# 3.
# To apply regularization to the linear regression model, use the equation l*np.identity(m.shape[0]). The regularization parameter 'l' in this case determines the degree to which we want to avoid overfitting, or the model fitting too closely to the training set. The square matrix produced by the np.identity(m.shape[0]) function matches the dimensions of our features matrix'm', with ones on the diagonal and zeros everywhere else. This regularization term guarantees the stability of the inversion process even in cases when the original matrix is almost singular when it is added to the matrix multiplication m.T.dot(m) during the pseudo-inverse computation. This method successfully controls the model weights, encouraging the use of smaller models that are probably going to work better with fresh, untested data.

# %% [markdown]
# # Task 3

# %% [markdown]
# Please add cells according to your own requirements.

# %%
# kf = KFold(n_splits=10, shuffle=True, random_state=42)

# model_performance = []

# for train_index, test_index in kf.split(X):
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

#     classifier4 = LinearRegression()
#     classifier4.fit(X_train, y_train)

#     y_pred = classifier4.predict(X_test)
#     mse = mean_squared_error(y_test, y_pred)
#     model_performance.append(mse)

# average_performance = np.mean(model_performance)
# print(f"Average MSE across all folds: {average_performance}")

# %%
X = data_frame[0].values
y = data_frame[1]

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=5)
folds = list(kf.split(X))

ein = []
eout = []

lambdas = np.linspace(0.001, 1, 100)
for l in lambdas:
    ein_folds = []
    eout_folds = []
    for train_index, test_index in folds:
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        X_train = transPoly(X_train, 50)
        X_test = transPoly(X_test, 50)
        w = weights_reg(X_train, y_train, l)
        ein_folds.append(calc_error(w, X_train, y_train))
        eout_folds.append(calc_error(w, X_test, y_test))
    ein.append(np.mean(ein_folds))
    eout.append(np.mean(eout_folds))

overfitted_lambda1 = 0.00001
underfitted_lambda1 = 0.5

weights_underfitted = weights_reg(X_train, y_train, underfitted_lambda1)
weights_optimal = weights_reg(X_train, y_train, opt_lambda)
weights_overfitted = weights_reg(X_train, y_train, overfitted_lambda1)

w_without_reg = weights_reg(X_train, y_train, 0)
eout_without_reg = calc_error(w_without_reg, X_test, y_test)

print(f"Optimal Regularization Parameter (lambda): {optimal_lambda}")
print(f"Eout without regularization: {eout_without_reg}")
print(f"Eout with optimal regularization (lambda={optimal_lambda}): {min_eout}")

l_opt = lambdas[np.argmin(eout)]
print(f'Optimal l: {l_opt}')
print(f'Eout with optimal regularization: {eout[np.argmin(eout)]:.4}')
# Out:
# Optimal Regularization Parameter (lambda): 0
# Eout without regularization: 0.7124130213264966
# Eout with optimal regularization (lambda=0): 0.02576333664795419
# Optimal l: 0.001
# Eout with optimal regularization: 0.02385

# %%
plt.figure(figsize=(10, 6))
plt.plot(lambdas, ein, label='Ein', color='blue')
plt.plot(lambdas, eout, label='Eout', color='orange')
plt.scatter(l_opt, min(eout), color='yellow', label='Optimal Lambda')
plt.xscale('log')
plt.xlabel('Lambda')
plt.ylabel('Error')
plt.title('Error vs Lambda')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))

# Plot for underfitted model
plt.subplot(1, 3, 1)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_underfitted, X_trans), color='orange', linestyle='--', label='Fitted model')
plt.title('Underfitted Model (λ=0.5)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# Plot for optimal model
plt.subplot(1, 3, 2)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_optimal, X_trans), color='green', linestyle='--', label='Fitted model')
plt.title(f'Optimal Model (λ={round(opt_lambda, 3)})')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# Plot for overfitted model
plt.subplot(1, 3, 3)
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, linreg_predict(weights_overfitted, X_trans), color='red', linestyle='--', label='Fitted model')
plt.title('Overfitted Model (λ=0.00001)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reflection
# In your reflection, explain the procedure followed by using KFOLDS and your choice of parameters.

# %% [markdown]
# I used a technique called 10-fold K-Folds cross-validation to see how well my Ridge and Lasso regression models were doing. This method allowed me to train and test the models on different sets of data to check their accuracy. I mixed up the data and set a random state to 42 to make sure the tests were fair and could be repeated the same way.
#
# I chose to use 10 folds because it was a good balance between getting reliable test results and not using too much computer power. A big part of what I did was adjusting something called the lambda parameter in the models. Lambda is important because it helps stop the models from fitting too tightly to the training data. It does this by simplifying the models when they start to get too complicated. My goal was to find the best lambda value that made the models work well not just on the data they were trained on, but also on new data they hadn't seen before.
#
# To do this, I used tools called RidgeCV and LassoCV from the sklearn library, which automatically find the best lambda value. I looked at lambda values from just a little bit above zero all the way up to one to cover a wide range. This helped me see how changing lambda affected the models' performance and helped me find the best balance. This was an important step in making the models predict more accurately.

# %% [markdown]
# # Task 4

# %%
features_train = transPoly(X, 50)

# %%
ridge_cv = RidgeCV(alphas=np.linspace(0.00000001, 1, 100), cv=10 )
lasso_cv = LassoCV(alphas=np.linspace(0.00000001, 1, 100), cv=10)

ridge_cv.fit(X_trans, y)
lasso_cv.fit(X_trans, y)
print(f"Ridge Weights: {ridge_cv.coef_}")
print(f"Lasso Weights: {lasso_cv.coef_}")

l_opt_ridge = ridge_cv.alpha_
l_opt_lasso = lasso_cv.alpha_

print(f'RidgeCV optimal l: {l_opt_ridge}')
print(f'LassoCV optimal l: {l_opt_lasso}')
print(f'Task 3 optimal l: {l_opt}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9138644487617168, tolerance: 0.0015448194694893099
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9263579827590801, tolerance: 0.0015768324495630882
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:617: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8915345513247984, tolerance: 0.0014504279641191745
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
eout_ridge = (w_ridge, X_trans, y)
eout_lasso = (w_lasso, X_trans, y)
eout_opt = (w_opt,X_trans, y)
print(eout_ridge)
print(eout_lasso)
print(eout_opt)
# Out:
# (array([-7.39795457e-02,  4.01525818e+00, -1.97635741e+00, -1.53960915e+00,
#        -6.10244119e-01, -5.79654019e-02,  1.68355153e-01,  2.11258038e-01,
#         1.71504503e-01,  1.05487560e-01,  4.06424232e-02, -1.18705915e-02,
#        -4.92164302e-02, -7.23984914e-02, -8.38904358e-02, -8.64668395e-02,
#        -8.26790118e-02, -7.46623147e-02, -6.41041243e-02, -5.22824914e-02,
#        -4.01299824e-02, -2.83009232e-02, -1.72326076e-02, -7.19720168e-03,
#         1.65600082e-03,  9.26707642e-03,  1.56394050e-02,  2.08196933e-02,
#         2.48828733e-02,  2.79208454e-02,  3.00342196e-02,  3.13263743e-02,
#         3.18992907e-02,  3.18507385e-02,  3.12724762e-02,  3.02492079e-02,
#         2.88580932e-02,  2.71686545e-02,  2.52429620e-02,  2.31360054e-02,
#         2.08961822e-02,  1.85658531e-02,  1.61819253e-02,  1.37764369e-02,
#         1.13771241e-02,  9.00795677e-03,  6.68963630e-03,  4.44005014e-03,
# ...

# %%
w_ridge = weights_reg(X_trans, y, l_opt_ridge)
w_lasso = weights_reg(X_trans, y, l_opt_lasso)
w_opt = weights_reg(X_trans, y, l_opt)

print(w_ridge)
print(w_lasso)
print(w_opt)
# Out:
# [-7.39795457e-02  4.01525818e+00 -1.97635741e+00 -1.53960915e+00
#  -6.10244119e-01 -5.79654019e-02  1.68355153e-01  2.11258038e-01
#   1.71504503e-01  1.05487560e-01  4.06424232e-02 -1.18705915e-02
#  -4.92164302e-02 -7.23984914e-02 -8.38904358e-02 -8.64668395e-02
#  -8.26790118e-02 -7.46623147e-02 -6.41041243e-02 -5.22824914e-02
#  -4.01299824e-02 -2.83009232e-02 -1.72326076e-02 -7.19720168e-03
#   1.65600082e-03  9.26707642e-03  1.56394050e-02  2.08196933e-02
#   2.48828733e-02  2.79208454e-02  3.00342196e-02  3.13263743e-02
#   3.18992907e-02  3.18507385e-02  3.12724762e-02  3.02492079e-02
#   2.88580932e-02  2.71686545e-02  2.52429620e-02  2.31360054e-02
#   2.08961822e-02  1.85658531e-02  1.61819253e-02  1.37764369e-02
#   1.13771241e-02  9.00795677e-03  6.68963630e-03  4.44005014e-03
#   2.27468127e-03  2.06972936e-04 -1.75135012e-03]
# [  -0.28787528    9.83087977  -49.77598952  172.49159579 -266.77112793
# ...

# %%
# Plot for underfitted model

plt.plot(w_ridge, color='red', linestyle='--', label='Ridge value')
plt.plot(w_lasso, color='orange', linestyle='--', label='Lasso value')
plt.plot(w_opt, color='blue', linestyle='--', label='Opt Value')
plt.title('Underfitted Model (λ=0.5)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ## Reflection

# %% [markdown]
# Please reflect on the following:
# - Observe the resulting error and l (lambda), and compare these to previous results. What do you see? Is this what you expected?
# - Compare the weights obtained with RidgeCV to those obtained with LassoCV. What do you see? Is this what you expected?

# %% [markdown]
# # My reflection
#
#
# When looking at the mistakes and the chosen lambda (λ) values, I found out that changing λ really affects how well the models work. It was super interesting to see that just by tweaking λ a little, you can make a big difference in avoiding errors. This made it clear how important it is to pick the right λ for improving our models, something I kind of knew already, but seeing it in action really proved it.
#
# I also noticed something cool when checking out the weights from RidgeCV and LassoCV. With RidgeCV, the weights were more spread out, which is what Ridge regression is supposed to do. But with LassoCV, some weights were made zero, meaning those features were ignored by the model. This is a special thing about Lasso regression. It was neat to see how Lasso makes models simpler by not paying attention to the features that aren't that important. This was something I expected to see, and it was really interesting to see it happening.
