# %% [markdown]
# <div>
# <img src="https://drive.google.com/uc?export=view&id=1vK33e_EqaHgBHcbRV_m38hx6IkG0blK_" width="350"/>
# </div>
#
#
# ## CS6402  Probabilistic and Explainable AI
# ## SEM2 2022/3
#
# ### CS6402 Etivity 1 - Probability
#
# ### Instructor: Emil Vassev
# Feb 7th, 2023
# <br><br>
# Copyright (C) 2023 - All rights reserved, do not copy or distribute without permission of the author.
# ***

# %% [markdown]
# ## Submission Info
# ### Student Name: <span style="color:red"> Vilohit</span>
# ### Student Surname: <span style="color:red"> Keshava Murhty Achar</span>
# ### Student ID: <span style="color:red"> 23077751</span>
# ### Date of Final Submission: <span style="color:red">26/02/2024 </span>
# ***

# %% [markdown]
# ## Introduction
# Suppose you have a bag full of diamonds of different cut, color, clarity. You draw diamonds without replacement.
#
# ## Task
# In this etivity, you are asked to implement a Python code that will determine the probability of getting diamonds of a specific cut, color and clarity.
#
# ## The Dataset
# The diamonds data can be loaded from the online repository hosted by the seaborn Python library.

# %% [markdown]
# The provided dataset can be loaded as following:

# %%
import seaborn as sns

df = sns.load_dataset('diamonds')

df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## Computing Probability
#
# Use the ```fractions``` library, which provides support for rational number arithmetic. Use the ```compute_probability``` function to calculate probability.
#
# For more information on ```fractions```, please consult the reference page here: https://docs.python.org/3/library/fractions.html#fractions.Fraction

# %%
from fractions import Fraction

cases = len # the number of cases is the length, or size, of a set
favorable = set.intersection # outcomes that are in the event and in the sample space

def compute_probability(event, space): ### The probability of an event, given a sample space.

    result = Fraction(cases(favorable(event, space)), cases(space))
    probability = result.numerator / result.denominator

    return probability

# %% [markdown]
# # Step 1: Determine the Sample Space Parameters.  (10%)

# %% [markdown]
# <span style="color:red">TODO</span>
#
# Define the Diamonds Sample Space as:
# * total number of diamonds
# * total number of diamonds in category of cut
# * total number of diamonds in category of color
# * total number of diamonds in category of clarity

# %%
#put your code here

# %%
No = len(df)
print('Total number of diamonds:',No)
# Out:
# Total number of diamonds: 53940

# %%
cut_counts = df['cut'].value_counts()
print(cut_counts)
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
color_counts = df['color'].value_counts()
print(color_counts)
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
clarity_counts = df['clarity'].value_counts()
print(clarity_counts)
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %% [markdown]
# # Step 2: Implement the Sample Space.  (30%)
#
# <span style="color:red">TODO</span>
#
# Implement a loop that will read the dataframe ```df``` and complete the ```diamonds``` sample space. The sample space must contain strings describing each diamond in the bag in terms of cut, color, and clarity.

# %%
diamonds= []

#put ypour code here

for index, row in df.iterrows():
    description = f"{row['cut']}, {row['color']}, {row['clarity']}"
    diamonds.append(description)

print(diamonds)
# Out:
# ['Ideal, E, SI2', 'Premium, E, SI1', 'Good, E, VS1', 'Premium, I, VS2', 'Good, J, SI2', 'Very Good, J, VVS2', 'Very Good, I, VVS1', 'Very Good, H, SI1', 'Fair, E, VS2', 'Very Good, H, VS1', 'Good, J, SI1', 'Ideal, J, VS1', 'Premium, F, SI1', 'Ideal, J, SI2', 'Premium, E, SI2', 'Premium, E, I1', 'Ideal, I, SI2', 'Good, J, SI1', 'Good, J, SI1', 'Very Good, J, SI1', 'Good, I, SI2', 'Very Good, E, VS2', 'Very Good, H, VS1', 'Very Good, J, SI1', 'Very Good, J, SI1', 'Very Good, G, VVS2', 'Premium, I, VS1', 'Very Good, J, VS2', 'Very Good, D, VS2', 'Very Good, F, VS1', 'Very Good, F, VS1', 'Very Good, F, VS1', 'Very Good, E, VS1', 'Very Good, E, VS1', 'Very Good, D, VS1', 'Good, F, VS1', 'Good, E, VS1', 'Good, H, SI1', 'Very Good, D, VS2', 'Ideal, I, SI2', 'Ideal, I, SI2', 'Ideal, J, SI1', 'Good, D, VS2', 'Good, D, VS1', 'Good, H, SI2', 'Premium, F, SI1', 'Very Good, H, SI2', 'Good, H, SI2', 'Very Good, E, VS2', 'Very Good, H, SI2', 'Very Good, F, SI1', 'Ideal, G, VS1', 'Ideal, I, SI1', 'P
# ...

# %% [markdown]
# # Step 3: Implement Events and Compute Probabilites.  (60%)

# %% [markdown]
# ## Step 3.1: Compute the Probability of Drawing Five Diamonds with "Ideal" Cut Consecutively?   (15%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with ideal cut"
# * compute the probability of drawing five diamonds with "ideal" cut consecutively and without replacement

# %% [markdown]
# # With Funtion:-

# %%
ideal_cut_diamonds = set(df[df['cut'] == 'Ideal'].index)
total_diamonds = set(df.index)
probabilities1 = []


for i in range(5):
    prob = compute_probability(ideal_cut_diamonds, total_diamonds)
    probabilities1.append(prob)
    if ideal_cut_diamonds:
        ideal_cut_diamonds.pop()
    total_diamonds.pop()

overall_probability = 1
for prob in probabilities1:
    overall_probability *= prob


print('Probability in each draw:', probabilities1)
print('Overall probability of drawing five diamonds with "Ideal" cut consecutively and without replacement:', overall_probability)
# Out:
# Probability in each draw: [0.3995365220615499, 0.3995253897921726, 0.3995142571100152, 0.3995031240150546, 0.39949199050726786]
# Overall probability of drawing five diamonds with "Ideal" cut consecutively and without replacement: 0.010177975640258418

# %% [markdown]
# # Without using function:-

# %%
ev_diamonds_with_ideal_cut = {}

#put ypour code here

ideal_cut_diamonds = df[df['cut'] == 'Ideal']

No_2 = len(ideal_cut_diamonds)

first_draw = No_2 / No

remaining_ideal = No_2 - 1
remaining_total = No - 1

# %%
print(first_draw)
print(remaining_ideal)
print(remaining_total)
# Out:
# 0.3995365220615499
# 21550
# 53939

# %%
second_draw = remaining_ideal / remaining_total
third_draw  = (remaining_ideal - 1) / (remaining_total - 1)
fourth_draw  = (remaining_ideal - 2) / (remaining_total - 2)
fifth_draw = (remaining_ideal - 3) / (remaining_total - 3)
overall_probability = first_draw * second_draw * third_draw * fourth_draw * fifth_draw

# %%
print('probabilty in the first draw:',first_draw)
print('probabilty in the second draw:',second_draw)
print('probabilty in the third draw:',third_draw)
print('probabilty in the fourth  draw:',fourth_draw)
print('probabilty in the five draw:',fifth_draw)
print('Overall probability of drawing five diamonds with "ideal" cut consecutively and without replacement:',overall_probability)
# Out:
# probabilty in the first draw: 0.3995365220615499
# probabilty in the second draw: 0.3995253897921726
# probabilty in the third draw: 0.3995142571100152
# probabilty in the fourth  draw: 0.3995031240150546
# probabilty in the five draw: 0.39949199050726786
# Overall probability of drawing five diamonds with "ideal" cut consecutively and without replacement: 0.010177975640258418

# %% [markdown]
# ## Step 3.2: Compute the Probability of Drawing Five Diamonds with "SI2" Clarity Consecutively?   (15%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with SI2 clarity"
# * compute the probability of drawing five diamonds with "SI2" clarity consecutively and without replacement

# %% [markdown]
# # with function:-

# %%
si2_clarity_diamonds = set(df[df['clarity'] == 'SI2'].index)
probabilities2 = []

for i in range(5):
    prob = compute_probability(si2_clarity_diamonds, total_diamonds)
    probabilities2.append(prob)

    if si2_clarity_diamonds:
        si2_clarity_diamonds.pop()
    total_diamonds.pop()

overall_probability = 1
for prob in probabilities2:
    overall_probability *= prob

print('Probability in each draw:', probabilities2)
print('Overall probability of drawing five diamonds with "SI2" clarity consecutively and without replacement:', overall_probability)
# Out:
# Probability in each draw: [0.17044316706842202, 0.17044632757885367, 0.17044948820649755, 0.17043410536465964, 0.170418721952305]
# Overall probability of drawing five diamonds with "SI2" clarity consecutively and without replacement: 0.00014382578551121617

# %% [markdown]
# # Without Function:-

# %%
ev_diamonds_with_si2_clarity = {}

#put ypour code here

si2_diamonds = df[df['clarity'] == 'SI2']

No_3 = len(si2_diamonds)
No_3
# Out:
# 9194

# %%
first1_draw = No_3 / No
remaining_clarity = No_3 - 1
second1_draw = remaining_clarity / remaining_total
third1_draw  = (remaining_clarity- 1) / (remaining_total - 1)
fourth1_draw  = (remaining_clarity - 2) / (remaining_total - 2)
fifth1_draw = (remaining_clarity - 3) / (remaining_total - 3)
overall1_probability = first1_draw * second1_draw * third1_draw * fourth1_draw * fifth1_draw




print('probabilty in the first draw:',first1_draw)
print('probabilty in the second draw:',second1_draw)
print('probabilty in the third draw:',third1_draw)
print('probabilty in the fourth  draw:',fourth1_draw)
print('probabilty in the five draw:',fifth1_draw)
print('Overall probability of drawing five diamonds with "SI2" cut consecutively and without replacement:',overall1_probability)
# Out:
# probabilty in the first draw: 0.17044864664441972
# probabilty in the second draw: 0.1704332672092549
# probabilty in the third draw: 0.1704178872038266
# probabilty in the fourth  draw: 0.17040250662810316
# probabilty in the five draw: 0.17038712548205281
# Overall probability of drawing five diamonds with "SI2" cut consecutively and without replacement: 0.00014373941027232868

# %% [markdown]
# ## Step 3.3: Compute the Probability of Drawing Five Diamonds with "E" Color Consecutively?   (15%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with E color"
# * compute the probability of drawing five diamonds with "E" color consecutively and without replacement

# %% [markdown]
# # With Function:-

# %%
e_color_diamonds = set(df[df['color'] == 'E'].index)
probabilities3 = []

for i in range(5):
    prob = compute_probability(e_color_diamonds, total_diamonds)
    probabilities3.append(prob)

    if e_color_diamonds:
        e_color_diamonds.pop()
    total_diamonds.pop()

overall_probability = 1
for prob in probabilities3:
    overall_probability *= prob

print('Probability in each draw:', probabilities3)
print('Overall probability of drawing five diamonds with "E" color consecutively and without replacement:', overall_probability)
# Out:
# Probability in each draw: [0.1815855354659249, 0.18157035828202656, 0.1815737254974686, 0.18157709283780274, 0.18158046030303593]
# Overall probability of drawing five diamonds with "E" color consecutively and without replacement: 0.0001973828326217194

# %% [markdown]
# # Without Function : -

# %%
ev_diamonds_with_e_color = {}

#put ypour code here

E_diamonds = df[df['color'] == 'E']

No_4 = len(E_diamonds)
No_4
# Out:
# 9797

# %%
first2_draw = No_4 / No
remaining_E = No_4 - 1
second2_draw = remaining_E / remaining_total
third2_draw  = (remaining_E- 1) / (remaining_total - 1)
fourth2_draw  = (remaining_E - 2) / (remaining_total - 2)
fifth2_draw = (remaining_E - 3) / (remaining_total - 3)
overall2_probability = first2_draw * second2_draw * third2_draw * fourth2_draw * fifth2_draw




print('probabilty in the first draw:',first2_draw)
print('probabilty in the second draw:',second2_draw)
print('probabilty in the third draw:',third2_draw)
print('probabilty in the fourth  draw:',fourth2_draw)
print('probabilty in the five draw:',fifth2_draw)
print('Overall probability of drawing five diamonds with "E" cut consecutively and without replacement:',overall2_probability)
# Out:
# probabilty in the first draw: 0.18162773451983685
# probabilty in the second draw: 0.18161256233893844
# probabilty in the third draw: 0.18159738959546146
# probabilty in the fourth  draw: 0.18158221628937465
# probabilty in the five draw: 0.1815670424206467
# Overall probability of drawing five diamonds with "E" cut consecutively and without replacement: 0.00019749130747843014

# %% [markdown]
# ## Step 3.4: Compute the Probability of Drawing Five Diamonds with "Ideal" cut, "SI2" Clarity, and "E" Color Consecutively?   (15%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with Ideal cut, SI2 clarity, and E color"
# * compute the probability of drawing five diamonds with "Ideal" cut, "SI2" clarity, and "E" color consecutively and without replacement

# %% [markdown]
# # With Function: -

# %%
ideal_si2_e_diamonds = set(df[(df['cut'] == 'Ideal') & (df['clarity'] == 'SI2') & (df['color'] == 'E')].index)

ev_diamonds_with_ideal_cut_si2_clarity_e_color = {}


for i in range(1, 6):
    prob = compute_probability(ideal_si2_e_diamonds, total_diamonds)
    ev_diamonds_with_ideal_cut_si2_clarity_e_color[f'draw_{i}'] = prob

    if ideal_si2_e_diamonds:
        ideal_si2_e_diamonds.pop()
    total_diamonds.pop()

overall_prob4 = 1
for key, value in ev_diamonds_with_ideal_cut_si2_clarity_e_color.items():
    overall_prob4 *= value

print("Probability of drawing five diamonds with 'Ideal' cut, 'SI2' clarity, and 'E' color consecutively without replacement:", overall_prob4)
# Out:
# Probability of drawing five diamonds with 'Ideal' cut, 'SI2' clarity, and 'E' color consecutively without replacement: 4.863832217545814e-11

# %% [markdown]
# # Without Function

# %%
ev_diamonds_with_ideal_cut_si2_clarity_e_color = {}

#put ypour code here


filter_diamonds = df[(df['cut'] == 'Ideal') & (df['clarity'] == 'SI2') & (df['color'] == 'E')]
diamonds_with_ideal_cut_SI2_clarity_e_color = len(filter_diamonds)

for i in range(1, 6):
    ev_diamonds_with_ideal_cut_si2_clarity_e_color[f'draw_{i}'] = (diamonds_with_ideal_cut_SI2_clarity_e_color - (i - 1)) / (No - (i - 1))

overall_prob4 = 1
for key, value in ev_diamonds_with_ideal_cut_si2_clarity_e_color.items():
    overall_prob4 *= value

overall_prob_flt4 = overall_prob4

print("Probability of drawing five diamonds with 'Ideal' cut, 'SI2' clarity, and 'E' color consecutively without replacement:", overall_prob_flt4)
# Out:
# Probability of drawing five diamonds with 'Ideal' cut, 'SI2' clarity, and 'E' color consecutively without replacement: 4.865195002375008e-11
